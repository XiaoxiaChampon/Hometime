# %%
# !pip install pyreadr
# Out:
# Requirement already satisfied: pyreadr in /Users/xzhao17/opt/anaconda3/lib/python3.9/site-packages (0.5.0)
# Requirement already satisfied: pandas>=1.2.0 in /Users/xzhao17/opt/anaconda3/lib/python3.9/site-packages (from pyreadr) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/xzhao17/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.2.0->pyreadr) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/xzhao17/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.2.0->pyreadr) (2023.3.post1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/xzhao17/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.2.0->pyreadr) (1.21.5)
# Requirement already satisfied: six>=1.5 in /Users/xzhao17/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.2.0->pyreadr) (1.16.0)
# WARNING: There was an error checking the latest version of pip.

# %%
import os.path
import pyreadr
import glob
import pandas as pd
import re

# %%
#DATA_DIR = "../hometimefinaldata"
DATA_DIR = "../march7result"
"""
How STUDY_TIME is calculated
----------------------------
1. Glob all files and folders inside DATA_DIR
2. For each path found:
3.     Take the name of the folder using os.path.basename (removing the long path name and taking only the name of the folder)
4.     Remove the "days" part from the folder name by using [:-4]
5.     Convert the remaining string to integer using int()
"""
STUDY_TIME = [int(os.path.basename(path)[:-4]) for path in glob.glob(DATA_DIR + "/*")]
STUDY_TIME
# Out:
# [90, 365]

# %%
#365
this_st = STUDY_TIME[1]
#90
#this_st = STUDY_TIME[0]

TYPE_I_DATA_FILES = DATA_DIR + f"/{this_st}days/typeI*"

glob.glob(TYPE_I_DATA_FILES)
# Out:
# ['../march7result/365days/typeI_3censor_balance.RData',
#  '../march7result/365days/typeI_smalldiffcensor_balance.RData',
#  '../march7result/365days/typeI_scensor_unbalance.RData',
#  '../march7result/365days/typeI_4censor_balance.RData',
#  '../march7result/365days/typeI_reversebigdiffcensor_unbalance.RData',
#  '../march7result/365days/typeI_3censor_unbalance.RData',
#  '../march7result/365days/typeI_uniformcensor_unbalance.RData',
#  '../march7result/365days/typeI_reversebigdiffcensor_balance.RData',
#  '../march7result/365days/typeI_uniformcensor_balance.RData',
#  '../march7result/365days/typeI_censor_unbalance.RData',
#  '../march7result/365days/typeI_uncensor_balance.RData',
#  '../march7result/365days/typeI_reversesmalldiffcensor_balance.RData',
#  '../march7result/365days/typeI_smalldiffcensor_unbalance.RData',
#  '../march7result/365days/typeI_reversesmalldiffcensor_unbalance.RData',
#  '../march7result/365days/typeI_censor_balance.RData',
#  '../march7result/365days/typeI_bigdiffcensor_unbalance.RData',
#  '../march7result/365days/typeI_bigdiffcensor_balance.RData',
#  '../march7result/365days/typeI_4censor_unbalance.RData',
#  '../march7result/365days/typeI_scensor_balance.RData',
#  '../march7result/365days/typeI_uncensor_unbalance.RData']

# %%
FILE_ATTRIBUTES = { os.path.basename(path): os.path.basename(path)[6:-6].split("_") for path in glob.glob(TYPE_I_DATA_FILES) }
FILE_ATTRIBUTES
# Out:
# {'typeI_3censor_balance.RData': ['3censor', 'balance'],
#  'typeI_smalldiffcensor_balance.RData': ['smalldiffcensor', 'balance'],
#  'typeI_scensor_unbalance.RData': ['scensor', 'unbalance'],
#  'typeI_4censor_balance.RData': ['4censor', 'balance'],
#  'typeI_reversebigdiffcensor_unbalance.RData': ['reversebigdiffcensor',
#   'unbalance'],
#  'typeI_3censor_unbalance.RData': ['3censor', 'unbalance'],
#  'typeI_uniformcensor_unbalance.RData': ['uniformcensor', 'unbalance'],
#  'typeI_reversebigdiffcensor_balance.RData': ['reversebigdiffcensor',
#   'balance'],
#  'typeI_uniformcensor_balance.RData': ['uniformcensor', 'balance'],
#  'typeI_censor_unbalance.RData': ['censor', 'unbalance'],
#  'typeI_uncensor_balance.RData': ['uncensor', 'balance'],
#  'typeI_reversesmalldiffcensor_balance.RData': ['reversesmalldiffcensor',
#   'balance'],
#  'typeI_smalldiffcensor_unbalance.RData': ['smalldiffcensor', 'unbalance'],
#  'typeI_reversesmalldiffcensor_unbalance.RData': ['reversesmalldiffcensor',
#   'unbalance'],
#  'typeI_censor_balance.RData': ['censor', 'balance'],
#  'typeI_bigdiffcensor_unbalance.RData': ['bigdiffcensor', 'unbalance'],
#  'typeI_bigdiffcensor_balance.RData': ['bigdiffcensor', 'balance'],
#  'typeI_4censor_unbalance.RData': ['4censor', 'unbalance'],
#  'typeI_scensor_balance.RData': ['scensor', 'balance'],
#  'typeI_uncensor_unbalance.RData': ['uncensor', 'unbalance']}

# %%
def read_one_variable_RData(file_path):
    type1 = pyreadr.read_r(file_path)
    return type1[ list(type1.keys())[0] ]

# %%
COLUMN_NAMES = {"lin": "Linear", "med": "Median", "poi": "Poisson", "nb": "Neg Bin", "cox":"Cox PH", "temp":"Temp Pro"}

# %%
EMPTY_LINE = '\\multicolumn{1}{l|}{} & \\multicolumn{1}{l|}{} & & & \\multicolumn{1}{l|}{} & & & \\\\'
EMPTY_LINE
# Out:
# '\\multicolumn{1}{l|}{} & \\multicolumn{1}{l|}{} & & & \\multicolumn{1}{l|}{} & & & \\\\'

# %%
PRE_TEXT = r"""\begin{table}[H]
\resizebox{\textwidth}{!}{
\begin{tabular}{llllllll}
                                           &                                       & \multicolumn{3}{c}{No Treatment Effect ($\rho=0$)}   & \multicolumn{3}{c}{Treatment Effect ($\rho =1$)} \\ \cline{3-8} 
n                                          & Methods                               & Estimate & SE ($\hat{\rho})$ & \multicolumn{1}{l|}{Type I Error Rate$^1$ (SE)} & Estimate           & Standard Error           & Power$^1 $(SE)          \\ \hline"""

print(PRE_TEXT)
# Out:
# \begin{table}[H]
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llllllll}
#                                            &                                       & \multicolumn{3}{c}{No Treatment Effect ($\rho=0$)}   & \multicolumn{3}{c}{Treatment Effect ($\rho =1$)} \\ \cline{3-8}
# n                                          & Methods                               & Estimate & SE ($\hat{\rho})$ & \multicolumn{1}{l|}{Type I Error Rate$^1$ (SE)} & Estimate           & Standard Error           & Power$^1 $(SE)          \\ \hline

# %%
POST_TEXT = r"""\bottomrule
\multicolumn{8}{l}{\small $^1$ $\alpha=0.05$} \\
\end{tabular}
}
\caption{ <caption/> }
\label{alpha365b}
\end{table}"""

print(POST_TEXT)
# Out:
# \bottomrule
# \multicolumn{8}{l}{\small $^1$ $\alpha=0.05$} \\
# \end{tabular}
# }
# \caption{ <caption/> }
# \label{alpha365b}
# \end{table}

# %%
POST_TEXT = r"""\bottomrule
\multicolumn{8}{l}{\small $^1$ $\alpha=0.05$} \\
\end{tabular}
}
\caption{ <caption/> }
\label{alpha90b}
\end{table}"""

print(POST_TEXT)
# Out:
# \bottomrule
# \multicolumn{8}{l}{\small $^1$ $\alpha=0.05$} \\
# \end{tabular}
# }
# \caption{ <caption/> }
# \label{alpha90b}
# \end{table}

# %%
re.sub("<caption/>", "HELLO", POST_TEXT)
# Out:
# '\\bottomrule\n\\multicolumn{8}{l}{\\small $^1$ $\\alpha=0.05$} \\\\\n\\end{tabular}\n}\n\\caption{ HELLO }\n\\label{alpha365b}\n\\end{table}'

# %%
def write_table(type1_error_rate, power_result):
    for offset in [0, 4, 8]:
        print(EMPTY_LINE)
        print("%================================")
        for idx in range(type1_error_rate.shape[0]):
            print("%", offset, type1_error_rate.iloc[idx].name, "\n%")
            tline = type1_error_rate.iloc[idx]
            pline = power_result.iloc[idx]
            col_name = COLUMN_NAMES[type1_error_rate.iloc[idx].name]
            num_indvs = {0: 500, 4: 1000, 8: 5000}[offset]
            multi_line_num_indv_str = f"\multirow{{6}}{{*}}{{{num_indvs}}}" if idx == 0 else ""
            short = f"\multicolumn{{1}}{{l|}}{{{multi_line_num_indv_str}}} & \multicolumn{{1}}{{l|}}{{{col_name}}} & \multicolumn{{1}}{{c}}{{{tline[offset + 0]:.2f}}} & \multicolumn{{1}}{{c}} {{{tline[offset + 1]:.2f}}} & \multicolumn{{1}}{{c|}}{{{tline[offset + 2]:.2f} ({tline[offset + 3]:.3f})}} & \multicolumn{{1}}{{c}}{{{pline[offset + 0]:.2f}}} & \multicolumn{{1}}{{c}}{{{pline[offset + 1]:.2f}}} & \multicolumn{{1}}{{c}}{{{pline[offset + 2]:.2f} ({pline[offset + 3]:.3f})}} \\\\"
            print(short)
            print("%----")

# %%
for censoring, balance in FILE_ATTRIBUTES.values():
    type1_file = f"{DATA_DIR}/{this_st}days/typeI_{censoring}_{balance}.RData"
    power_file = f"{DATA_DIR}/{this_st}days/power_{censoring}_{balance}.RData"
    type1_error_rate = read_one_variable_RData(type1_file)
    power_result = read_one_variable_RData(power_file)
    print(PRE_TEXT)
    write_table(type1_error_rate, power_result)
    post_text = re.sub("<caption/>", f"{censoring} {balance}", POST_TEXT)
    print(post_text)
    print("\n\n\n")
# Out:
# \begin{table}[H]
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llllllll}
#                                            &                                       & \multicolumn{3}{c}{No Treatment Effect ($\rho=0$)}   & \multicolumn{3}{c}{Treatment Effect ($\rho =1$)} \\ \cline{3-8}
# n                                          & Methods                               & Estimate & SE ($\hat{\rho})$ & \multicolumn{1}{l|}{Type I Error Rate$^1$ (SE)} & Estimate           & Standard Error           & Power$^1 $(SE)          \\ \hline
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 0 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{500}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{3.99} & \multicolumn{1}{c} {0.40} & \multicolumn{1}{c|}{0.00 (0.000)} & \multicolumn{1}{c}{12.79} & \multicolumn{1}{c}{0.60} & \multicolumn{1}{c}{0.16 (0.005)} \\
# %----
# % 0 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{11.15} & \multicolumn{1}{c} {1.12} & \multicolumn{1}{c|}{0.00 (0.000)} & \multicolumn{1}{c}{16.55} & \multicolumn{1}{c}{2.16} & \multicolumn{1}{c}{0.30 (0.006)} \\
# %----
# % 0 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.02} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.00 (0.000)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.16 (0.005)} \\
# %----
# % 0 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.02} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.00 (0.000)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.16 (0.005)} \\
# %----
# % 0 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.23} & \multicolumn{1}{c} {0.01} & \multicolumn{1}{c|}{0.00 (0.000)} & \multicolumn{1}{c}{-0.91} & \multicolumn{1}{c}{0.08} & \multicolumn{1}{c}{0.22 (0.006)} \\
# %----
# % 0 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-3.39} & \multicolumn{1}{c} {0.43} & \multicolumn{1}{c|}{0.00 (0.000)} & \multicolumn{1}{c}{-17.18} & \multicolumn{1}{c}{0.65} & \multicolumn{1}{c}{0.23 (0.006)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 4 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{1000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{-0.10} & \multicolumn{1}{c} {0.29} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{12.43} & \multicolumn{1}{c}{0.29} & \multicolumn{1}{c}{0.26 (0.006)} \\
# %----
# % 4 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{-0.35} & \multicolumn{1}{c} {1.04} & \multicolumn{1}{c|}{0.20 (0.006)} & \multicolumn{1}{c}{15.14} & \multicolumn{1}{c}{1.11} & \multicolumn{1}{c}{0.26 (0.006)} \\
# %----
# % 4 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.26 (0.006)} \\
# %----
# % 4 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.26 (0.006)} \\
# %----
# % 4 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.01} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-0.74} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c}{0.45 (0.007)} \\
# %----
# % 4 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{0.08} & \multicolumn{1}{c} {0.32} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-16.83} & \multicolumn{1}{c}{0.32} & \multicolumn{1}{c}{0.38 (0.007)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 8 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{5000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.11} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{12.68} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.86 (0.005)} \\
# %----
# % 8 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.36} & \multicolumn{1}{c} {0.22} & \multicolumn{1}{c|}{0.09 (0.004)} & \multicolumn{1}{c}{15.52} & \multicolumn{1}{c}{0.23} & \multicolumn{1}{c}{0.22 (0.006)} \\
# %----
# % 8 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.86 (0.005)} \\
# %----
# % 8 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.86 (0.005)} \\
# %----
# % 8 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-0.73} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.99 (0.001)} \\
# %----
# % 8 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.13} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.06} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.96 (0.003)} \\
# %----
# \bottomrule
# \multicolumn{8}{l}{\small $^1$ $\alpha=0.05$} \\
# \end{tabular}
# }
# \caption{ 3censor balance }
# \label{alpha365b}
# \end{table}
#
#
#
#
# \begin{table}[H]
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llllllll}
#                                            &                                       & \multicolumn{3}{c}{No Treatment Effect ($\rho=0$)}   & \multicolumn{3}{c}{Treatment Effect ($\rho =1$)} \\ \cline{3-8}
# n                                          & Methods                               & Estimate & SE ($\hat{\rho})$ & \multicolumn{1}{l|}{Type I Error Rate$^1$ (SE)} & Estimate           & Standard Error           & Power$^1 $(SE)          \\ \hline
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 0 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{500}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.11} & \multicolumn{1}{c} {0.59} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{14.76} & \multicolumn{1}{c}{0.60} & \multicolumn{1}{c}{0.20 (0.006)} \\
# %----
# % 0 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.35} & \multicolumn{1}{c} {1.61} & \multicolumn{1}{c|}{0.22 (0.006)} & \multicolumn{1}{c}{33.27} & \multicolumn{1}{c}{1.82} & \multicolumn{1}{c}{0.46 (0.007)} \\
# %----
# % 0 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.20 (0.006)} \\
# %----
# % 0 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.20 (0.006)} \\
# %----
# % 0 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c} {0.02} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{-0.87} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.21 (0.006)} \\
# %----
# % 0 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.15} & \multicolumn{1}{c} {0.61} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.24} & \multicolumn{1}{c}{0.62} & \multicolumn{1}{c}{0.23 (0.006)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 4 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{1000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.20} & \multicolumn{1}{c} {0.30} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{14.90} & \multicolumn{1}{c}{0.30} & \multicolumn{1}{c}{0.36 (0.007)} \\
# %----
# % 4 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.67} & \multicolumn{1}{c} {0.82} & \multicolumn{1}{c|}{0.24 (0.006)} & \multicolumn{1}{c}{35.34} & \multicolumn{1}{c}{0.95} & \multicolumn{1}{c}{0.65 (0.007)} \\
# %----
# % 4 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.36 (0.007)} \\
# %----
# % 4 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.36 (0.007)} \\
# %----
# % 4 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c} {0.01} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{-0.76} & \multicolumn{1}{c}{0.02} & \multicolumn{1}{c}{0.45 (0.007)} \\
# %----
# % 4 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.18} & \multicolumn{1}{c} {0.31} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.32} & \multicolumn{1}{c}{0.31} & \multicolumn{1}{c}{0.42 (0.007)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 8 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{5000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{14.78} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.95 (0.003)} \\
# %----
# % 8 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.19} & \multicolumn{1}{c} {0.16} & \multicolumn{1}{c|}{0.19 (0.006)} & \multicolumn{1}{c}{36.95} & \multicolumn{1}{c}{0.19} & \multicolumn{1}{c}{0.96 (0.003)} \\
# %----
# % 8 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.95 (0.003)} \\
# %----
# % 8 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.95 (0.003)} \\
# %----
# % 8 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-0.73} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.99 (0.001)} \\
# %----
# % 8 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.05} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.20} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.97 (0.002)} \\
# %----
# \bottomrule
# \multicolumn{8}{l}{\small $^1$ $\alpha=0.05$} \\
# \end{tabular}
# }
# \caption{ smalldiffcensor balance }
# \label{alpha365b}
# \end{table}
#
#
#
#
# \begin{table}[H]
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llllllll}
#                                            &                                       & \multicolumn{3}{c}{No Treatment Effect ($\rho=0$)}   & \multicolumn{3}{c}{Treatment Effect ($\rho =1$)} \\ \cline{3-8}
# n                                          & Methods                               & Estimate & SE ($\hat{\rho})$ & \multicolumn{1}{l|}{Type I Error Rate$^1$ (SE)} & Estimate           & Standard Error           & Power$^1 $(SE)          \\ \hline
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 0 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{500}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{-0.21} & \multicolumn{1}{c} {0.59} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{14.01} & \multicolumn{1}{c}{0.60} & \multicolumn{1}{c}{0.17 (0.005)} \\
# %----
# % 0 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.18} & \multicolumn{1}{c} {1.76} & \multicolumn{1}{c|}{0.23 (0.006)} & \multicolumn{1}{c}{28.64} & \multicolumn{1}{c}{1.97} & \multicolumn{1}{c}{0.39 (0.007)} \\
# %----
# % 0 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.17 (0.005)} \\
# %----
# % 0 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.18 (0.005)} \\
# %----
# % 0 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.03} & \multicolumn{1}{c} {0.03} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{-0.78} & \multicolumn{1}{c}{0.05} & \multicolumn{1}{c}{0.25 (0.006)} \\
# %----
# % 0 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{0.22} & \multicolumn{1}{c} {0.62} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-16.72} & \multicolumn{1}{c}{0.63} & \multicolumn{1}{c}{0.21 (0.006)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 4 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{1000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{-0.03} & \multicolumn{1}{c} {0.30} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{14.16} & \multicolumn{1}{c}{0.30} & \multicolumn{1}{c}{0.31 (0.007)} \\
# %----
# % 4 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.84} & \multicolumn{1}{c} {0.90} & \multicolumn{1}{c|}{0.23 (0.006)} & \multicolumn{1}{c}{29.71} & \multicolumn{1}{c}{1.04} & \multicolumn{1}{c}{0.51 (0.007)} \\
# %----
# % 4 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.31 (0.007)} \\
# %----
# % 4 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.32 (0.007)} \\
# %----
# % 4 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.02} & \multicolumn{1}{c} {0.01} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{-0.73} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c}{0.46 (0.007)} \\
# %----
# % 4 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.04} & \multicolumn{1}{c} {0.32} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-16.95} & \multicolumn{1}{c}{0.32} & \multicolumn{1}{c}{0.40 (0.007)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 8 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{5000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{14.20} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.91 (0.004)} \\
# %----
# % 8 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.26} & \multicolumn{1}{c} {0.19} & \multicolumn{1}{c|}{0.18 (0.005)} & \multicolumn{1}{c}{29.70} & \multicolumn{1}{c}{0.22} & \multicolumn{1}{c}{0.80 (0.006)} \\
# %----
# % 8 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.91 (0.004)} \\
# %----
# % 8 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.91 (0.004)} \\
# %----
# % 8 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-0.72} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.99 (0.002)} \\
# %----
# % 8 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{-16.91} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.97 (0.002)} \\
# %----
# \bottomrule
# \multicolumn{8}{l}{\small $^1$ $\alpha=0.05$} \\
# \end{tabular}
# }
# \caption{ scensor unbalance }
# \label{alpha365b}
# \end{table}
#
#
#
#
# \begin{table}[H]
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llllllll}
#                                            &                                       & \multicolumn{3}{c}{No Treatment Effect ($\rho=0$)}   & \multicolumn{3}{c}{Treatment Effect ($\rho =1$)} \\ \cline{3-8}
# n                                          & Methods                               & Estimate & SE ($\hat{\rho})$ & \multicolumn{1}{l|}{Type I Error Rate$^1$ (SE)} & Estimate           & Standard Error           & Power$^1 $(SE)          \\ \hline
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 0 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{500}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.27} & \multicolumn{1}{c} {0.59} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{14.96} & \multicolumn{1}{c}{0.60} & \multicolumn{1}{c}{0.21 (0.006)} \\
# %----
# % 0 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{1.14} & \multicolumn{1}{c} {1.62} & \multicolumn{1}{c|}{0.21 (0.006)} & \multicolumn{1}{c}{34.67} & \multicolumn{1}{c}{1.81} & \multicolumn{1}{c}{0.49 (0.007)} \\
# %----
# % 0 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.21 (0.006)} \\
# %----
# % 0 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.21 (0.006)} \\
# %----
# % 0 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.02} & \multicolumn{1}{c|}{0.03 (0.003)} & \multicolumn{1}{c}{-0.90} & \multicolumn{1}{c}{0.08} & \multicolumn{1}{c}{0.20 (0.006)} \\
# %----
# % 0 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.20} & \multicolumn{1}{c} {0.62} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.34} & \multicolumn{1}{c}{0.62} & \multicolumn{1}{c}{0.25 (0.006)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 4 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{1000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.29} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{14.71} & \multicolumn{1}{c}{0.30} & \multicolumn{1}{c}{0.35 (0.007)} \\
# %----
# % 4 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c} {0.80} & \multicolumn{1}{c|}{0.24 (0.006)} & \multicolumn{1}{c}{34.71} & \multicolumn{1}{c}{0.93} & \multicolumn{1}{c}{0.64 (0.007)} \\
# %----
# % 4 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.35 (0.007)} \\
# %----
# % 4 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.35 (0.007)} \\
# %----
# % 4 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.01} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-0.76} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c}{0.46 (0.007)} \\
# %----
# % 4 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c} {0.31} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.16} & \multicolumn{1}{c}{0.31} & \multicolumn{1}{c}{0.42 (0.007)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 8 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{5000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{-0.05} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{14.66} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.93 (0.003)} \\
# %----
# % 8 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{-0.07} & \multicolumn{1}{c} {0.17} & \multicolumn{1}{c|}{0.20 (0.006)} & \multicolumn{1}{c}{36.62} & \multicolumn{1}{c}{0.19} & \multicolumn{1}{c}{0.95 (0.003)} \\
# %----
# % 8 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.93 (0.003)} \\
# %----
# % 8 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.93 (0.003)} \\
# %----
# % 8 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-0.73} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.99 (0.001)} \\
# %----
# % 8 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{0.08} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.06} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.97 (0.002)} \\
# %----
# \bottomrule
# \multicolumn{8}{l}{\small $^1$ $\alpha=0.05$} \\
# \end{tabular}
# }
# \caption{ 4censor balance }
# \label{alpha365b}
# \end{table}
#
#
#
#
# \begin{table}[H]
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llllllll}
#                                            &                                       & \multicolumn{3}{c}{No Treatment Effect ($\rho=0$)}   & \multicolumn{3}{c}{Treatment Effect ($\rho =1$)} \\ \cline{3-8}
# n                                          & Methods                               & Estimate & SE ($\hat{\rho})$ & \multicolumn{1}{l|}{Type I Error Rate$^1$ (SE)} & Estimate           & Standard Error           & Power$^1 $(SE)          \\ \hline
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 0 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{500}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.08} & \multicolumn{1}{c} {0.59} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{12.94} & \multicolumn{1}{c}{0.60} & \multicolumn{1}{c}{0.16 (0.005)} \\
# %----
# % 0 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.90} & \multicolumn{1}{c} {2.02} & \multicolumn{1}{c|}{0.26 (0.006)} & \multicolumn{1}{c}{18.29} & \multicolumn{1}{c}{2.16} & \multicolumn{1}{c}{0.30 (0.007)} \\
# %----
# % 0 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.15 (0.005)} \\
# %----
# % 0 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.16 (0.005)} \\
# %----
# % 0 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c} {0.03} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{-0.79} & \multicolumn{1}{c}{0.04} & \multicolumn{1}{c}{0.26 (0.006)} \\
# %----
# % 0 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.21} & \multicolumn{1}{c} {0.64} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.29} & \multicolumn{1}{c}{0.65} & \multicolumn{1}{c}{0.22 (0.006)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 4 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{1000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{-0.02} & \multicolumn{1}{c} {0.30} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{12.84} & \multicolumn{1}{c}{0.30} & \multicolumn{1}{c}{0.27 (0.006)} \\
# %----
# % 4 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.11} & \multicolumn{1}{c} {1.05} & \multicolumn{1}{c|}{0.22 (0.006)} & \multicolumn{1}{c}{17.48} & \multicolumn{1}{c}{1.12} & \multicolumn{1}{c}{0.29 (0.006)} \\
# %----
# % 4 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.26 (0.006)} \\
# %----
# % 4 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.27 (0.006)} \\
# %----
# % 4 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c} {0.01} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-0.74} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c}{0.47 (0.007)} \\
# %----
# % 4 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.01} & \multicolumn{1}{c} {0.32} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.08} & \multicolumn{1}{c}{0.33} & \multicolumn{1}{c}{0.38 (0.007)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 8 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{5000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{12.87} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.85 (0.005)} \\
# %----
# % 8 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.15} & \multicolumn{1}{c} {0.22} & \multicolumn{1}{c|}{0.11 (0.004)} & \multicolumn{1}{c}{17.16} & \multicolumn{1}{c}{0.23} & \multicolumn{1}{c}{0.28 (0.006)} \\
# %----
# % 8 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.85 (0.005)} \\
# %----
# % 8 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.85 (0.005)} \\
# %----
# % 8 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-0.73} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.99 (0.002)} \\
# %----
# % 8 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.02} & \multicolumn{1}{c} {0.07} & \multicolumn{1}{c|}{0.06 (0.003)} & \multicolumn{1}{c}{-17.10} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.95 (0.003)} \\
# %----
# \bottomrule
# \multicolumn{8}{l}{\small $^1$ $\alpha=0.05$} \\
# \end{tabular}
# }
# \caption{ reversebigdiffcensor unbalance }
# \label{alpha365b}
# \end{table}
#
#
#
#
# \begin{table}[H]
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llllllll}
#                                            &                                       & \multicolumn{3}{c}{No Treatment Effect ($\rho=0$)}   & \multicolumn{3}{c}{Treatment Effect ($\rho =1$)} \\ \cline{3-8}
# n                                          & Methods                               & Estimate & SE ($\hat{\rho})$ & \multicolumn{1}{l|}{Type I Error Rate$^1$ (SE)} & Estimate           & Standard Error           & Power$^1 $(SE)          \\ \hline
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 0 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{500}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.08} & \multicolumn{1}{c} {0.59} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{12.94} & \multicolumn{1}{c}{0.60} & \multicolumn{1}{c}{0.16 (0.005)} \\
# %----
# % 0 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.90} & \multicolumn{1}{c} {2.02} & \multicolumn{1}{c|}{0.26 (0.006)} & \multicolumn{1}{c}{18.29} & \multicolumn{1}{c}{2.16} & \multicolumn{1}{c}{0.30 (0.007)} \\
# %----
# % 0 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.15 (0.005)} \\
# %----
# % 0 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.16 (0.005)} \\
# %----
# % 0 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c} {0.03} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{-0.79} & \multicolumn{1}{c}{0.04} & \multicolumn{1}{c}{0.26 (0.006)} \\
# %----
# % 0 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.21} & \multicolumn{1}{c} {0.64} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.29} & \multicolumn{1}{c}{0.65} & \multicolumn{1}{c}{0.22 (0.006)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 4 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{1000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{-0.02} & \multicolumn{1}{c} {0.30} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{12.84} & \multicolumn{1}{c}{0.30} & \multicolumn{1}{c}{0.27 (0.006)} \\
# %----
# % 4 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.11} & \multicolumn{1}{c} {1.05} & \multicolumn{1}{c|}{0.22 (0.006)} & \multicolumn{1}{c}{17.48} & \multicolumn{1}{c}{1.12} & \multicolumn{1}{c}{0.29 (0.006)} \\
# %----
# % 4 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.26 (0.006)} \\
# %----
# % 4 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.27 (0.006)} \\
# %----
# % 4 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c} {0.01} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-0.74} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c}{0.47 (0.007)} \\
# %----
# % 4 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.01} & \multicolumn{1}{c} {0.32} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.08} & \multicolumn{1}{c}{0.33} & \multicolumn{1}{c}{0.38 (0.007)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 8 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{5000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{12.87} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.85 (0.005)} \\
# %----
# % 8 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.15} & \multicolumn{1}{c} {0.22} & \multicolumn{1}{c|}{0.11 (0.004)} & \multicolumn{1}{c}{17.16} & \multicolumn{1}{c}{0.23} & \multicolumn{1}{c}{0.28 (0.006)} \\
# %----
# % 8 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.85 (0.005)} \\
# %----
# % 8 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.85 (0.005)} \\
# %----
# % 8 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-0.73} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.99 (0.002)} \\
# %----
# % 8 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.02} & \multicolumn{1}{c} {0.07} & \multicolumn{1}{c|}{0.06 (0.003)} & \multicolumn{1}{c}{-17.10} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.95 (0.003)} \\
# %----
# \bottomrule
# \multicolumn{8}{l}{\small $^1$ $\alpha=0.05$} \\
# \end{tabular}
# }
# \caption{ 3censor unbalance }
# \label{alpha365b}
# \end{table}
#
#
#
#
# \begin{table}[H]
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llllllll}
#                                            &                                       & \multicolumn{3}{c}{No Treatment Effect ($\rho=0$)}   & \multicolumn{3}{c}{Treatment Effect ($\rho =1$)} \\ \cline{3-8}
# n                                          & Methods                               & Estimate & SE ($\hat{\rho})$ & \multicolumn{1}{l|}{Type I Error Rate$^1$ (SE)} & Estimate           & Standard Error           & Power$^1 $(SE)          \\ \hline
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 0 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{500}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.16} & \multicolumn{1}{c} {0.50} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{8.15} & \multicolumn{1}{c}{0.50} & \multicolumn{1}{c}{0.12 (0.005)} \\
# %----
# % 0 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.22} & \multicolumn{1}{c} {0.52} & \multicolumn{1}{c|}{0.00 (0.001)} & \multicolumn{1}{c}{3.95} & \multicolumn{1}{c}{0.52} & \multicolumn{1}{c}{0.00 (0.001)} \\
# %----
# % 0 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.05} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.11 (0.004)} \\
# %----
# % 0 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.05} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.12 (0.005)} \\
# %----
# % 0 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.02} & \multicolumn{1}{c} {0.03} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{-0.78} & \multicolumn{1}{c}{0.05} & \multicolumn{1}{c}{0.23 (0.006)} \\
# %----
# % 0 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.17} & \multicolumn{1}{c} {0.59} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-11.17} & \multicolumn{1}{c}{0.60} & \multicolumn{1}{c}{0.13 (0.005)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 4 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{1000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.04} & \multicolumn{1}{c} {0.25} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{8.04} & \multicolumn{1}{c}{0.25} & \multicolumn{1}{c}{0.17 (0.005)} \\
# %----
# % 4 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{-0.03} & \multicolumn{1}{c} {0.26} & \multicolumn{1}{c|}{0.01 (0.001)} & \multicolumn{1}{c}{3.68} & \multicolumn{1}{c}{0.26} & \multicolumn{1}{c}{0.01 (0.002)} \\
# %----
# % 4 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.04} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.17 (0.005)} \\
# %----
# % 4 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.04} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.18 (0.005)} \\
# %----
# % 4 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c} {0.01} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{-0.73} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c}{0.47 (0.007)} \\
# %----
# % 4 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.06} & \multicolumn{1}{c} {0.30} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-11.07} & \multicolumn{1}{c}{0.30} & \multicolumn{1}{c}{0.22 (0.006)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 8 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{5000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{-0.02} & \multicolumn{1}{c} {0.05} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{8.01} & \multicolumn{1}{c}{0.05} & \multicolumn{1}{c}{0.63 (0.007)} \\
# %----
# % 8 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{-0.03} & \multicolumn{1}{c} {0.05} & \multicolumn{1}{c|}{0.02 (0.002)} & \multicolumn{1}{c}{3.80} & \multicolumn{1}{c}{0.05} & \multicolumn{1}{c}{0.10 (0.004)} \\
# %----
# % 8 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.04} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.62 (0.007)} \\
# %----
# % 8 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.04} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.63 (0.007)} \\
# %----
# % 8 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-0.73} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.99 (0.002)} \\
# %----
# % 8 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{0.02} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-11.01} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.73 (0.006)} \\
# %----
# \bottomrule
# \multicolumn{8}{l}{\small $^1$ $\alpha=0.05$} \\
# \end{tabular}
# }
# \caption{ uniformcensor unbalance }
# \label{alpha365b}
# \end{table}
#
#
#
#
# \begin{table}[H]
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llllllll}
#                                            &                                       & \multicolumn{3}{c}{No Treatment Effect ($\rho=0$)}   & \multicolumn{3}{c}{Treatment Effect ($\rho =1$)} \\ \cline{3-8}
# n                                          & Methods                               & Estimate & SE ($\hat{\rho})$ & \multicolumn{1}{l|}{Type I Error Rate$^1$ (SE)} & Estimate           & Standard Error           & Power$^1 $(SE)          \\ \hline
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 0 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{500}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{3.99} & \multicolumn{1}{c} {0.40} & \multicolumn{1}{c|}{0.00 (0.000)} & \multicolumn{1}{c}{12.79} & \multicolumn{1}{c}{0.60} & \multicolumn{1}{c}{0.16 (0.005)} \\
# %----
# % 0 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{11.15} & \multicolumn{1}{c} {1.12} & \multicolumn{1}{c|}{0.00 (0.000)} & \multicolumn{1}{c}{16.55} & \multicolumn{1}{c}{2.16} & \multicolumn{1}{c}{0.30 (0.006)} \\
# %----
# % 0 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.02} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.00 (0.000)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.16 (0.005)} \\
# %----
# % 0 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.02} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.00 (0.000)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.16 (0.005)} \\
# %----
# % 0 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.23} & \multicolumn{1}{c} {0.01} & \multicolumn{1}{c|}{0.00 (0.000)} & \multicolumn{1}{c}{-0.91} & \multicolumn{1}{c}{0.08} & \multicolumn{1}{c}{0.22 (0.006)} \\
# %----
# % 0 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-3.39} & \multicolumn{1}{c} {0.43} & \multicolumn{1}{c|}{0.00 (0.000)} & \multicolumn{1}{c}{-17.18} & \multicolumn{1}{c}{0.65} & \multicolumn{1}{c}{0.23 (0.006)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 4 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{1000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{-0.10} & \multicolumn{1}{c} {0.29} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{12.43} & \multicolumn{1}{c}{0.29} & \multicolumn{1}{c}{0.26 (0.006)} \\
# %----
# % 4 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{-0.35} & \multicolumn{1}{c} {1.04} & \multicolumn{1}{c|}{0.20 (0.006)} & \multicolumn{1}{c}{15.14} & \multicolumn{1}{c}{1.11} & \multicolumn{1}{c}{0.26 (0.006)} \\
# %----
# % 4 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.26 (0.006)} \\
# %----
# % 4 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.26 (0.006)} \\
# %----
# % 4 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.01} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-0.74} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c}{0.45 (0.007)} \\
# %----
# % 4 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{0.08} & \multicolumn{1}{c} {0.32} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-16.83} & \multicolumn{1}{c}{0.32} & \multicolumn{1}{c}{0.38 (0.007)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 8 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{5000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.11} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{12.68} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.86 (0.005)} \\
# %----
# % 8 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.36} & \multicolumn{1}{c} {0.22} & \multicolumn{1}{c|}{0.09 (0.004)} & \multicolumn{1}{c}{15.52} & \multicolumn{1}{c}{0.23} & \multicolumn{1}{c}{0.22 (0.006)} \\
# %----
# % 8 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.86 (0.005)} \\
# %----
# % 8 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.86 (0.005)} \\
# %----
# % 8 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-0.73} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.99 (0.001)} \\
# %----
# % 8 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.13} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.06} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.96 (0.003)} \\
# %----
# \bottomrule
# \multicolumn{8}{l}{\small $^1$ $\alpha=0.05$} \\
# \end{tabular}
# }
# \caption{ reversebigdiffcensor balance }
# \label{alpha365b}
# \end{table}
#
#
#
#
# \begin{table}[H]
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llllllll}
#                                            &                                       & \multicolumn{3}{c}{No Treatment Effect ($\rho=0$)}   & \multicolumn{3}{c}{Treatment Effect ($\rho =1$)} \\ \cline{3-8}
# n                                          & Methods                               & Estimate & SE ($\hat{\rho})$ & \multicolumn{1}{l|}{Type I Error Rate$^1$ (SE)} & Estimate           & Standard Error           & Power$^1 $(SE)          \\ \hline
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 0 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{500}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{-0.07} & \multicolumn{1}{c} {0.49} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{7.95} & \multicolumn{1}{c}{0.49} & \multicolumn{1}{c}{0.11 (0.004)} \\
# %----
# % 0 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{-0.01} & \multicolumn{1}{c} {0.51} & \multicolumn{1}{c|}{0.00 (0.001)} & \multicolumn{1}{c}{3.68} & \multicolumn{1}{c}{0.51} & \multicolumn{1}{c}{0.00 (0.001)} \\
# %----
# % 0 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.04} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.11 (0.004)} \\
# %----
# % 0 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.04} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.11 (0.004)} \\
# %----
# % 0 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c} {0.02} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{-0.89} & \multicolumn{1}{c}{0.08} & \multicolumn{1}{c}{0.20 (0.006)} \\
# %----
# % 0 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{0.09} & \multicolumn{1}{c} {0.59} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-10.95} & \multicolumn{1}{c}{0.60} & \multicolumn{1}{c}{0.13 (0.005)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 4 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{1000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{-0.04} & \multicolumn{1}{c} {0.24} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{7.99} & \multicolumn{1}{c}{0.24} & \multicolumn{1}{c}{0.18 (0.005)} \\
# %----
# % 4 med
# %
# ...
# %----
# % 0 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.20 (0.006)} \\
# %----
# % 0 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.21 (0.006)} \\
# %----
# % 0 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.03} & \multicolumn{1}{c} {0.03} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{-0.76} & \multicolumn{1}{c}{0.05} & \multicolumn{1}{c}{0.24 (0.006)} \\
# %----
# % 0 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.38} & \multicolumn{1}{c} {0.63} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.66} & \multicolumn{1}{c}{0.63} & \multicolumn{1}{c}{0.25 (0.006)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 4 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{1000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.02} & \multicolumn{1}{c} {0.30} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{14.99} & \multicolumn{1}{c}{0.30} & \multicolumn{1}{c}{0.34 (0.007)} \\
# %----
# % 4 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.79} & \multicolumn{1}{c} {0.74} & \multicolumn{1}{c|}{0.21 (0.006)} & \multicolumn{1}{c}{38.00} & \multicolumn{1}{c}{0.83} & \multicolumn{1}{c}{0.70 (0.006)} \\
# %----
# % 4 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.34 (0.007)} \\
# %----
# % 4 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.35 (0.007)} \\
# %----
# % 4 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c} {0.01} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{-0.73} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c}{0.45 (0.007)} \\
# %----
# % 4 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.06} & \multicolumn{1}{c} {0.31} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.30} & \multicolumn{1}{c}{0.31} & \multicolumn{1}{c}{0.42 (0.007)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 8 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{5000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.08} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{15.07} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.94 (0.003)} \\
# %----
# % 8 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.42} & \multicolumn{1}{c} {0.15} & \multicolumn{1}{c|}{0.21 (0.006)} & \multicolumn{1}{c}{39.50} & \multicolumn{1}{c}{0.16} & \multicolumn{1}{c}{0.99 (0.001)} \\
# %----
# % 8 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.94 (0.003)} \\
# %----
# % 8 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.94 (0.003)} \\
# %----
# % 8 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.06 (0.003)} & \multicolumn{1}{c}{-0.73} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.99 (0.002)} \\
# %----
# % 8 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.11} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.38} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.97 (0.002)} \\
# %----
# \bottomrule
# \multicolumn{8}{l}{\small $^1$ $\alpha=0.05$} \\
# \end{tabular}
# }
# \caption{ 4censor unbalance }
# \label{alpha365b}
# \end{table}
#
#
#
#
# \begin{table}[H]
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llllllll}
#                                            &                                       & \multicolumn{3}{c}{No Treatment Effect ($\rho=0$)}   & \multicolumn{3}{c}{Treatment Effect ($\rho =1$)} \\ \cline{3-8}
# n                                          & Methods                               & Estimate & SE ($\hat{\rho})$ & \multicolumn{1}{l|}{Type I Error Rate$^1$ (SE)} & Estimate           & Standard Error           & Power$^1 $(SE)          \\ \hline
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 0 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{500}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.11} & \multicolumn{1}{c} {0.59} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{14.76} & \multicolumn{1}{c}{0.60} & \multicolumn{1}{c}{0.20 (0.006)} \\
# %----
# % 0 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.35} & \multicolumn{1}{c} {1.61} & \multicolumn{1}{c|}{0.22 (0.006)} & \multicolumn{1}{c}{33.27} & \multicolumn{1}{c}{1.82} & \multicolumn{1}{c}{0.46 (0.007)} \\
# %----
# % 0 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.20 (0.006)} \\
# %----
# % 0 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.20 (0.006)} \\
# %----
# % 0 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c} {0.02} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{-0.87} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.21 (0.006)} \\
# %----
# % 0 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.15} & \multicolumn{1}{c} {0.61} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.24} & \multicolumn{1}{c}{0.62} & \multicolumn{1}{c}{0.23 (0.006)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 4 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{1000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.20} & \multicolumn{1}{c} {0.30} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{14.90} & \multicolumn{1}{c}{0.30} & \multicolumn{1}{c}{0.36 (0.007)} \\
# %----
# % 4 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.67} & \multicolumn{1}{c} {0.82} & \multicolumn{1}{c|}{0.24 (0.006)} & \multicolumn{1}{c}{35.34} & \multicolumn{1}{c}{0.95} & \multicolumn{1}{c}{0.65 (0.007)} \\
# %----
# % 4 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.36 (0.007)} \\
# %----
# % 4 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.36 (0.007)} \\
# %----
# % 4 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c} {0.01} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{-0.76} & \multicolumn{1}{c}{0.02} & \multicolumn{1}{c}{0.45 (0.007)} \\
# %----
# % 4 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.18} & \multicolumn{1}{c} {0.31} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.32} & \multicolumn{1}{c}{0.31} & \multicolumn{1}{c}{0.42 (0.007)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 8 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{5000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{14.78} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.95 (0.003)} \\
# %----
# % 8 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.19} & \multicolumn{1}{c} {0.16} & \multicolumn{1}{c|}{0.19 (0.006)} & \multicolumn{1}{c}{36.95} & \multicolumn{1}{c}{0.19} & \multicolumn{1}{c}{0.96 (0.003)} \\
# %----
# % 8 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.95 (0.003)} \\
# %----
# % 8 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.95 (0.003)} \\
# %----
# % 8 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-0.73} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.99 (0.001)} \\
# %----
# % 8 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.05} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.20} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.97 (0.002)} \\
# %----
# \bottomrule
# \multicolumn{8}{l}{\small $^1$ $\alpha=0.05$} \\
# \end{tabular}
# }
# \caption{ scensor balance }
# \label{alpha365b}
# \end{table}
#
#
#
#
# \begin{table}[H]
# \resizebox{\textwidth}{!}{
# \begin{tabular}{llllllll}
#                                            &                                       & \multicolumn{3}{c}{No Treatment Effect ($\rho=0$)}   & \multicolumn{3}{c}{Treatment Effect ($\rho =1$)} \\ \cline{3-8}
# n                                          & Methods                               & Estimate & SE ($\hat{\rho})$ & \multicolumn{1}{l|}{Type I Error Rate$^1$ (SE)} & Estimate           & Standard Error           & Power$^1 $(SE)          \\ \hline
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 0 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{500}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.60} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{17.53} & \multicolumn{1}{c}{0.60} & \multicolumn{1}{c}{0.25 (0.006)} \\
# %----
# % 0 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.80} & \multicolumn{1}{c} {0.73} & \multicolumn{1}{c|}{0.03 (0.002)} & \multicolumn{1}{c}{37.30} & \multicolumn{1}{c}{0.64} & \multicolumn{1}{c}{0.53 (0.007)} \\
# %----
# % 0 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.08} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.25 (0.006)} \\
# %----
# % 0 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{0.08} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.26 (0.006)} \\
# %----
# % 0 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.03} & \multicolumn{1}{c} {0.03} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{-0.79} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.24 (0.006)} \\
# %----
# % 0 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.00} & \multicolumn{1}{c} {0.60} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.49} & \multicolumn{1}{c}{0.60} & \multicolumn{1}{c}{0.26 (0.006)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 4 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{1000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.04} & \multicolumn{1}{c} {0.30} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{17.58} & \multicolumn{1}{c}{0.30} & \multicolumn{1}{c}{0.45 (0.007)} \\
# %----
# % 4 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.35} & \multicolumn{1}{c} {0.35} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{37.08} & \multicolumn{1}{c}{0.30} & \multicolumn{1}{c}{0.97 (0.002)} \\
# %----
# % 4 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.08} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.45 (0.007)} \\
# %----
# % 4 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.08} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.45 (0.007)} \\
# %----
# % 4 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c} {0.01} & \multicolumn{1}{c|}{0.04 (0.003)} & \multicolumn{1}{c}{-0.74} & \multicolumn{1}{c}{0.01} & \multicolumn{1}{c}{0.46 (0.007)} \\
# %----
# % 4 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.04} & \multicolumn{1}{c} {0.30} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.53} & \multicolumn{1}{c}{0.30} & \multicolumn{1}{c}{0.45 (0.007)} \\
# %----
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# %================================
# % 8 lin
# %
# \multicolumn{1}{l|}{\multirow{6}{*}{5000}} & \multicolumn{1}{l|}{Linear} & \multicolumn{1}{c}{0.07} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{17.59} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.98 (0.002)} \\
# %----
# % 8 med
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Median} & \multicolumn{1}{c}{0.17} & \multicolumn{1}{c} {0.07} & \multicolumn{1}{c|}{0.12 (0.005)} & \multicolumn{1}{c}{36.95} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{1.00 (0.000)} \\
# %----
# % 8 poi
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Poisson} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.08} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.98 (0.002)} \\
# %----
# % 8 nb
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Neg Bin} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{0.08} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.98 (0.002)} \\
# %----
# % 8 cox
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Cox PH} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c} {0.00} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-0.73} & \multicolumn{1}{c}{0.00} & \multicolumn{1}{c}{0.99 (0.002)} \\
# %----
# % 8 temp
# %
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{Temp Pro} & \multicolumn{1}{c}{-0.07} & \multicolumn{1}{c} {0.06} & \multicolumn{1}{c|}{0.05 (0.003)} & \multicolumn{1}{c}{-17.55} & \multicolumn{1}{c}{0.06} & \multicolumn{1}{c}{0.98 (0.002)} \\
# %----
# \bottomrule
# \multicolumn{8}{l}{\small $^1$ $\alpha=0.05$} \\
# \end{tabular}
# }
# \caption{ uncensor unbalance }
# \label{alpha365b}
# \end{table}

# %%
type1_error_rate = read_one_variable_RData( DATA_DIR + f"/{this_st}days/typeI_4censor_unbalance.RData" )
type1_error_rate
# Out:
#            est        se   power   powerse       est        se   power  \
# lin   0.362302  0.603238  0.0518  0.003134  0.017892  0.296549  0.0482
# med   2.627899  1.499428  0.1784  0.005414  0.791069  0.743953  0.2078
# poi   0.002206  0.002982  0.0488  0.003047  0.000305  0.001465  0.0480
# nb    0.002206  0.002982  0.0516  0.003128  0.000305  0.001465  0.0484
# cox  -0.003052  0.004242  0.0484  0.003035 -0.000548  0.002134  0.0486
# temp -0.375971  0.626823  0.0496  0.003070 -0.056359  0.306386  0.0506
#
#        powerse       est        se   power   powerse
# lin   0.003029  0.079355  0.059787  0.0504  0.003094
# med   0.005738  0.417621  0.150005  0.2052  0.005711
# poi   0.003023  0.000437  0.000295  0.0514  0.003123
# nb    0.003035  0.000437  0.000295  0.0504  0.003094
# cox   0.003041 -0.000665  0.000428  0.0506  0.003100
# temp  0.003100 -0.109710  0.062160  0.0526  0.003157

# %%
power_result = read_one_variable_RData( DATA_DIR + f"/{this_st}days/power_scensor_balance.RData" )
power_result
# Out:
#             est        se   power   powerse        est        se   power  \
# lin   14.762537  0.595049  0.1970  0.005625  14.900744  0.301903  0.3578
# med   33.268727  1.821170  0.4636  0.007052  35.344139  0.947640  0.6456
# poi    0.071044  0.002866  0.1980  0.005636   0.071629  0.001453  0.3586
# nb     0.071044  0.002866  0.1950  0.005603   0.071629  0.001453  0.3560
# cox   -0.469173  0.004374  0.9990  0.000447  -0.468952  0.002230  1.0000
# temp -17.238860  0.617691  0.2350  0.005996 -17.322398  0.314753  0.4246
#
#        powerse        est        se   power   powerse
# lin   0.006779  14.777787  0.058529  0.9472  0.003163
# med   0.006765  36.947404  0.188561  0.9558  0.002907
# poi   0.006782   0.070995  0.000281  0.9474  0.003157
# nb    0.006771   0.070995  0.000281  0.9472  0.003163
# cox   0.000000  -0.466970  0.000439  1.0000  0.000000
# temp  0.006990 -17.198165  0.061493  0.9750  0.002208

# %%
mystr = r"\multicolumn{1}{l|}{}                      & \multicolumn{1}{l|}{}                 &          &                & \multicolumn{1}{l|}{}                  &                    &                          &                \\"
mystr = re.sub(r"\s+", " ", mystr)
# mystr = re.sub(r"{", "{{", mystr)
# mystr = re.sub(r"}", "}}", mystr)
print(mystr)
mystr
# Out:
# \multicolumn{1}{l|}{} & \multicolumn{1}{l|}{} & & & \multicolumn{1}{l|}{} & & & \\
# '\\multicolumn{1}{l|}{} & \\multicolumn{1}{l|}{} & & & \\multicolumn{1}{l|}{} & & & \\\\'
